# %% [markdown]
# <a href="https://colab.research.google.com/github/amith-rs/amith-rs/blob/main/Q1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
forecast_data = pd.read_excel('Exhibit_10.xlsx', usecols='A,I,J')
forecast_data
# Out:
#         Style  Average Forecast  Standard Deviation
# 0        Gail              1017               194.0
# 1        Isis              1042               323.0
# 2      Entice              1358               248.0
# 3     Assault              2525               340.0
# 4        Teri              1100               381.0
# 5     Electra              2150               404.0
# 6   Stephanie              1113               524.0
# 7     Seduced              4017               556.0
# 8       Anita              3296              1047.0
# 9      Daphne              2383               697.0
# 10     Totals             20000                 NaN

# %%
prod_0 = 10000
#this is our intial production committment, I just called prod_0 cause idk what else to call it

# %% [markdown]
# - Ok so I'll make this nicer in the report but for now what i'm doing is:
# - We need to add a saftey stock of one standard deviation for items with a high variability in this case (im choosing arbitrarilly) when standard deviation > 500 . why ? We do this because we want to have something to act as a buffer against variability in demand.
#
# - Next we need to distribute prod_0 based on the proportion of the average forecast. To the total sum of the average forecasts + factoring the high variance styles/items.

# %%
# Remove the row where 'Style' is 'Totals'
forecast_data = forecast_data[forecast_data['Style'] != 'Totals']

# %%
taf = 20000

# %%
#now I am going to calculate the total proportion for each style:
forecast_data ['Proportion'] = forecast_data['Average Forecast']/taf

forecast_data
# Out:
# <ipython-input-25-5b3845372a01>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_data ['Proportion'] = forecast_data['Average Forecast']/taf
#        Style  Average Forecast  Standard Deviation  Proportion
# 0       Gail              1017               194.0     0.05085
# 1       Isis              1042               323.0     0.05210
# 2     Entice              1358               248.0     0.06790
# 3    Assault              2525               340.0     0.12625
# 4       Teri              1100               381.0     0.05500
# 5    Electra              2150               404.0     0.10750
# 6  Stephanie              1113               524.0     0.05565
# 7    Seduced              4017               556.0     0.20085
# ...

# %% [markdown]
# Ok so there's some weirdness with the data, If you actually total up the average forecast it comes up to 20001 instead of 20000, which is dodgy. I double checked it in the original excel file and the original doc but idk  seems like there was no actual calculation taken place, its just a 1 and i have no idea which one is the typo, so I'll make a note of it now since it doesn't seem to make a huge change and might get swallowed up later with rounding etc.
#
# Anyway this is just a proof of concept.  This code will get cleaned up later this week, tryna just see if everything works

# %%
# assigning initial order quantity based off the assigned proportions.
forecast_data['InitialOrderQuantity'] = forecast_data['Proportion'] * prod_0
forecast_data
# Out:
# <ipython-input-28-6624fc69a2bb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_data['InitialOrderQuantity'] = forecast_data['Proportion'] * prod_0
#        Style  Average Forecast  Standard Deviation  Proportion  \
# 0       Gail              1017               194.0     0.05085
# 1       Isis              1042               323.0     0.05210
# 2     Entice              1358               248.0     0.06790
# 3    Assault              2525               340.0     0.12625
# 4       Teri              1100               381.0     0.05500
# 5    Electra              2150               404.0     0.10750
# 6  Stephanie              1113               524.0     0.05565
# 7    Seduced              4017               556.0     0.20085
# ...

# %%
#now I need to adjust this for items/styles with a higher variability ( so adding one standard deviation to the initial order quantity)
forecast_data['AdjustedOrderQuantity'] = forecast_data.apply(
    lambda x: x['InitialOrderQuantity'] + x['Standard Deviation'] if x['Standard Deviation'] > 500 else x['InitialOrderQuantity'],
    axis=1
)

forecast_data
# Out:
# <ipython-input-31-deeaff6d6cb6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_data['AdjustedOrderQuantity'] = forecast_data.apply(
#        Style  Average Forecast  Standard Deviation  Proportion  \
# 0       Gail              1017               194.0     0.05085
# 1       Isis              1042               323.0     0.05210
# 2     Entice              1358               248.0     0.06790
# 3    Assault              2525               340.0     0.12625
# 4       Teri              1100               381.0     0.05500
# 5    Electra              2150               404.0     0.10750
# 6  Stephanie              1113               524.0     0.05565
# 7    Seduced              4017               556.0     0.20085
# ...

# %%
total_ioquant = forecast_data['InitialOrderQuantity'].sum() #initial order quantity total
total_ioquant
# Out:
# 10000.5

# %%
total_adjqaunt = forecast_data['AdjustedOrderQuantity'].sum() #adjusted order quantity total
total_adjqaunt
# Out:
# 12824.5

# %% [markdown]
# ok so this is weird since it exceeds our initial prod values.

# %% [markdown]
# Apparantly the solution is to scale it back a bit ? idk if I even need to do this ? Maybe better to just use the inital allocations since it can be rounded to 10000 ? A potential question to ask TAs. In the mean time I'll work out the scale back.

# %%
if forecast_data['AdjustedOrderQuantity'].sum() > initial_production_commitment:
    scale_back_factor = initial_production_commitment / forecast_data['AdjustedOrderQuantity'].sum()
    forecast_data['AdjustedOrderQuantity'] *= scale_back_factor

forecast_data
# Out:
#        Style  Average Forecast  Standard Deviation  Proportion  \
# 0       Gail              1017               194.0     0.05085
# 1       Isis              1042               323.0     0.05210
# 2     Entice              1358               248.0     0.06790
# 3    Assault              2525               340.0     0.12625
# 4       Teri              1100               381.0     0.05500
# 5    Electra              2150               404.0     0.10750
# 6  Stephanie              1113               524.0     0.05565
# 7    Seduced              4017               556.0     0.20085
# 8      Anita              3296              1047.0     0.16480
# 9     Daphne              2383               697.0     0.11915
#
#    InitialOrderQuantity  AdjustedOrderQuantity
# 0                 508.5             396.506686
# 1                 521.0             406.253655
# 2                 679.0             529.455339
# 3                1262.5             984.443838
# ...

# %%
total_adjqaunt = forecast_data['AdjustedOrderQuantity'].sum() #adjusted order quantity total
total_adjqaunt
# Out:
# 10000.0

# %% [markdown]
# nvm it works perfectly now haha.
#
# now we need to round all the order quanities since yk i cant order a decimal of a jacket

# %%
forecast_data['AdjustedOrderQuantity'] = forecast_data['AdjustedOrderQuantity'].round()
forecast_data['InitialOrderQuantity'] = forecast_data['InitialOrderQuantity'].round()
forecast_data
# Out:
# <ipython-input-44-8cc53767e5ba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_data['AdjustedOrderQuantity'] = forecast_data['AdjustedOrderQuantity'].round()
# <ipython-input-44-8cc53767e5ba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   forecast_data['InitialOrderQuantity'] = forecast_data['InitialOrderQuantity'].round()
#        Style  Average Forecast  Standard Deviation  Proportion  \
# 0       Gail              1017               194.0     0.05085
# ...

# %%
#checking to see if it still totals 10000
total_order_after_rounding = forecast_data['AdjustedOrderQuantity'].sum() , forecast_data['InitialOrderQuantity'].sum()

total_order_after_rounding
# Out:
# (10000.0, 9999.0)

# %% [markdown]
# Ok works perfectly for adjusted, smth to still be said about initialorderquanitty which is still being a bit weird. changes to be made. but as proof ? we go it.
